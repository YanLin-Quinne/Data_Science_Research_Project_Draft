# %%
#general package
import json
import os
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np
import matplotlib.cm as cm
import matplotlib.pyplot as plt
from matplotlib.ticker import FixedLocator, FixedFormatter
import seaborn as sns
from dateutil.parser import parse
from itertools import combinations
 
#statistical package
from scipy.stats import pearsonr
from scipy.stats import chi2_contingency
from scipy.stats import ttest_ind
from scipy import stats

#pre-process: encoding, pca, clustering
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans, AgglomerativeClustering
from sklearn.metrics import silhouette_score, silhouette_samples, calinski_harabasz_score, adjusted_rand_score

from scipy.cluster.hierarchy import dendrogram, linkage, cut_tree

#modelling
from sklearn.model_selection import cross_val_score, KFold
from sklearn.model_selection import StratifiedKFold
from sklearn.feature_selection import RFECV
from sklearn.model_selection import GridSearchCV

import statsmodels.api as sm
from itertools import chain, combinations
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC

from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score, accuracy_score
from sklearn.metrics import classification_report

# %%
df_bat = pd.read_csv('/Users/quinne/Desktop/dissertation_dataset/halftime_encode_python.csv')
df_bat
# Out:
#      Result  match_number  team_code  opponent_code  gender  season  \
# 0         1             5          4              1       0    2021
# 1         1             6          0              2       0    2021
# 2         1             7          3              6       0    2021
# 3         0             8          7              5       0    2021
# 4         1            10          6              1       0    2021
# ..      ...           ...        ...            ...     ...     ...
# 110       0            30          1              0       1    2022
# 111       1            31          3              5       1    2022
# 112       0            32          4              2       1    2022
# 113       0            40          1              2       1    2022
# 114       0            50          2              6       1    2022
#
#      team_score  team_wickets  winner_code  toss_winner_code  home_advantage  \
# 0           132             7            4                 1               0
# 1           113             9            0                 0               0
# 2           149             7            3                 3               0
# 3           110             7            5                 5               1
# 4           151             4            6                 6               0
# ..          ...           ...          ...               ...             ...
# 110         139             6            0                 0               1
# 111         135             8            3                 5               1
# 112         143             9            2                 4               0
# 113         150             7            2                 1               0
# 114         120             9            6                 2               0
#
#      venue_city_code  choose_to_bat   avg_score  avg_win_rate  \
# 0                  1              0  139.000000      1.000000
# 1                  2              1  128.000000      0.000000
# 2                  6              1  131.000000      1.000000
# 3                  7              0  130.000000      0.000000
# 4                  1              1  116.000000      0.000000
# ..               ...            ...         ...           ...
# 110                1              0  140.642857      0.428571
# 111                3              0  152.714286      0.428571
# 112                2              1  145.500000      0.571429
# 113                2              1  140.533333      0.400000
# 114                6              1  148.800000      0.533333
#
#      avg_wickets_out  last_match_result
# 0           5.000000                  1
# 1           6.000000                  0
# 2           4.000000                  1
# 3           8.000000                  0
# 4           7.000000                  0
# ..               ...                ...
# 110         6.571429                  0
# 111         6.000000                  1
# 112         5.785714                  1
# 113         6.533333                  0
# 114         6.000000                  1
#
# [115 rows x 17 columns]

# %%
X = df_bat.drop("Result", axis=1)
y = df_bat['Result']

# %%
cv = StratifiedKFold(n_splits=10, shuffle=True, random_state=5)

# %% [markdown]
# ### KNN (K-Nearest Neighbors)

# %%
# Standardizing the data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Finding the optimal parameters for KNN
knn = KNeighborsClassifier()
param_grid = {
    'n_neighbors': np.arange(1, 51),
    'weights': ['uniform', 'distance'],
    'metric': ['euclidean', 'manhattan']
}

knn_gscv = GridSearchCV(knn, param_grid, cv=10, scoring='accuracy')
knn_gscv.fit(X_scaled, y)

print("Best parameters for KNN:", knn_gscv.best_params_)
# Out:
# Best parameters for KNN: {'metric': 'euclidean', 'n_neighbors': 9, 'weights': 'uniform'}

# %%
knn = KNeighborsClassifier(metric='euclidean', n_neighbors=9, weights='uniform')
y_prob_knn = np.zeros_like(y, dtype=float)

for train_idx, test_idx in cv.split(X, y):
    scaler = StandardScaler()
    
    X_train = scaler.fit_transform(X.iloc[train_idx])
    X_test = scaler.transform(X.iloc[test_idx])
    
    y_train, y_test = y.iloc[train_idx], y.iloc[test_idx]
    
    knn.fit(X_train, y_train)
    y_prob_knn[test_idx] = knn.predict_proba(X_test)[:, 1]

y_pred_knn = (y_prob_knn > 0.5).astype(int)

print("Predicted Probabilities for KNN:")
print(y_prob_knn)
# Out:
# Predicted Probabilities for KNN:
# [0.44444444 0.44444444 0.44444444 0.22222222 0.55555556 0.22222222
#  0.11111111 0.33333333 0.55555556 0.44444444 0.44444444 0.66666667
#  0.22222222 0.77777778 0.33333333 0.33333333 0.22222222 0.44444444
#  1.         0.55555556 0.33333333 0.33333333 0.44444444 0.66666667
#  0.33333333 0.11111111 0.44444444 0.44444444 0.33333333 0.11111111
#  0.33333333 0.33333333 0.22222222 0.44444444 0.44444444 0.33333333
#  0.33333333 0.11111111 0.55555556 0.66666667 0.33333333 0.22222222
#  0.33333333 1.         0.66666667 0.11111111 0.55555556 0.66666667
#  0.55555556 0.11111111 0.33333333 0.44444444 0.22222222 0.22222222
#  0.55555556 0.44444444 0.33333333 0.55555556 0.66666667 0.55555556
#  0.44444444 0.44444444 0.55555556 0.44444444 0.66666667 0.55555556
#  0.55555556 0.66666667 0.22222222 0.33333333 0.33333333 0.22222222
#  0.33333333 0.33333333 0.33333333 0.33333333 0.22222222 0.55555556
#  0.44444444 0.77777778 0.22222222 0.11111111 0.66666667 0.55555556
#  0.22222222 0.44444444 0.55555556 0.44444444 0.66666667 0.44444444
#  0.44444444 0.88888889 0.55555556 0.44444444 0.44444444 0.44444444
#  0.55555556 0.44444444 0.66666667 0.44444444 0.22222222 0.77777778
#  0.44444444 0.77777778 0.77777778 0.33333333 0.44444444 0.44444444
#  0.44444444 0.44444444 0.44444444 0.44444444 0.33333333 0.44444444
#  0.        ]

# %%
# Evaluation for KNN
mat_knn = confusion_matrix(y, y_pred_knn)
sns.heatmap(mat_knn.T, square=True, annot=True, fmt="d", cmap="RdPu")
plt.xlabel("True label")
plt.ylabel("Predicted label")
plt.title("KNN")
plt.show()

print("Accuracy:\t%f" % accuracy_score(y, y_pred_knn))
print("F1-score:\t%f" % f1_score(y, y_pred_knn, average='macro'))
print("Precision:\t%f" % precision_score(y, y_pred_knn, average='macro'))
print("Recall:\t\t%f" % recall_score(y, y_pred_knn, average='macro'))
print("\nClassification performance:\n%s" % classification_report(y, y_pred_knn))
# Out:
# Accuracy:	0.721739
# F1-score:	0.705506
# Precision:	0.736990
# Recall:		0.705739
#
# Classification performance:
#               precision    recall  f1-score   support
#
#            0       0.70      0.87      0.77        63
#            1       0.78      0.54      0.64        52
#
#     accuracy                           0.72       115
#    macro avg       0.74      0.71      0.71       115
# weighted avg       0.73      0.72      0.71       115

# %% [markdown]
# ### SVM (Support Vector Machine)

# %%
#Finding the optimal parameters for SVM
svm = SVC(probability=True)
param_grid = {
    'C': [0.001, 0.01, 0.1, 1, 10, 100, 1000],
    'kernel': ['linear', 'rbf'],
    'gamma': ['scale', 'auto']}

svm_gscv = GridSearchCV(svm, param_grid, cv=10, scoring='accuracy')
svm_gscv.fit(X_scaled, y)

print("Best parameters for SVM:", svm_gscv.best_params_)
# Out:
# Best parameters for SVM: {'C': 10, 'gamma': 'auto', 'kernel': 'rbf'}

# %%
# svm = SVC(kernel='linear', probability=True)
svm = SVC(C=10, gamma='auto', kernel='rbf', probability=True)
y_prob_svm = np.zeros_like(y, dtype=float)

for train_idx, test_idx in cv.split(X, y):
    scaler = StandardScaler()
    
    X_train = scaler.fit_transform(X.iloc[train_idx])
    X_test = scaler.transform(X.iloc[test_idx])
    
    y_train, y_test = y.iloc[train_idx], y.iloc[test_idx]
    
    svm.fit(X_train, y_train)
    y_prob_svm[test_idx] = svm.predict_proba(X_test)[:, 1]

y_pred_svm = (y_prob_svm > 0.5).astype(int)
print("\nPredicted Probabilities for SVM:")
print(y_prob_svm)
# Out:
# Predicted Probabilities for SVM:
# [0.6720148  0.52731351 0.38096079 0.17972851 0.68490463 0.27534396
#  0.18376246 0.35022144 0.83540561 0.2000949  0.59900876 0.28411465
#  0.24273451 0.84510479 0.64292003 0.39939474 0.32279358 0.36355274
#  0.98558423 0.71171103 0.14530687 0.20381273 0.09105315 0.79808953
#  0.42091062 0.21369972 0.13046905 0.54080038 0.30048899 0.27839584
#  0.45511994 0.67017726 0.12091339 0.69770929 0.11922362 0.04144058
#  0.56704272 0.2116185  0.85025942 0.80331587 0.61204456 0.12383724
#  0.2558029  0.99484428 0.3582148  0.24841918 0.39113482 0.98127513
#  0.47630171 0.01014012 0.12894998 0.52125573 0.33401139 0.05102299
#  0.70821583 0.59626828 0.35931972 0.5135925  0.87629658 0.34811836
#  0.44903354 0.39138346 0.58387675 0.31062715 0.90054729 0.72651161
#  0.86634515 0.5        0.518488   0.31891752 0.35449041 0.07905157
#  0.18564227 0.33721563 0.46616097 0.37893838 0.25895551 0.77705407
#  0.28632149 0.88574596 0.39718305 0.15138666 0.5869152  0.50659469
#  0.27739281 0.29159521 0.60955554 0.76093741 0.8708676  0.36969692
#  0.46709976 0.40797656 0.93158337 0.60413896 0.15181648 0.24665149
#  0.72792253 0.6451487  0.90087549 0.69065982 0.07512166 0.93859345
#  0.04797682 0.67204216 0.94947712 0.47014871 0.61457311 0.36477988
#  0.57643719 0.83926661 0.4549245  0.16071495 0.15607063 0.43373324
#  0.06823054]

# %%
mat_svm = confusion_matrix(y, y_pred_svm)
sns.heatmap(mat_svm.T, square=True, annot=True, fmt="d", cmap="RdPu")
plt.xlabel("True label")
plt.ylabel("Predicted label")
plt.title("SVM")
plt.show()

print("Accuracy:\t%f" % accuracy_score(y, y_pred_svm))
print("F1-score:\t%f" % f1_score(y, y_pred_svm, average='macro'))
print("Precision:\t%f" % precision_score(y, y_pred_svm, average='macro'))
print("Recall:\t\t%f" % recall_score(y, y_pred_svm, average='macro'))
print("\nClassification performance:\n%s" % classification_report(y, y_pred_svm))
# Out:
# Accuracy:	0.756522
# F1-score:	0.752308
# Precision:	0.755597
# Recall:		0.750916
#
# Classification performance:
#               precision    recall  f1-score   support
#
#            0       0.76      0.81      0.78        63
#            1       0.75      0.69      0.72        52
#
#     accuracy                           0.76       115
#    macro avg       0.76      0.75      0.75       115
# weighted avg       0.76      0.76      0.76       115

# %% [markdown]
# ### Deep Netural Networks

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.wrappers.scikit_learn import KerasClassifier

# %%
def create_model(dropout_rate=0.0, activation='relu'):
    model = Sequential()
    model.add(Dense(16, input_dim=16, activation=activation))
    model.add(Dropout(dropout_rate))
    model.add(Dense(8, activation=activation))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

# %%
model = KerasClassifier(build_fn=create_model, verbose=0)

param_grid = {
    'batch_size': [10, 20, 30, 40],
    'epochs': [10, 50, 100],
    'dropout_rate': [0.0, 0.1, 0.2, 0.3],
    'activation': ['relu', 'tanh']
}

grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=-1, cv=10)
grid_result = grid.fit(X_scaled, y)

print("Best parameters found: ", grid_result.best_params_)
print('Best score', grid_result.best_score_)
# Out:
# 2023-08-23 16:20:48.174762: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2023-08-23 16:20:48.235578: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2023-08-23 16:20:48.312919: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2023-08-23 16:20:48.375086: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2023-08-23 16:20:48.385097: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2023-08-23 16:20:48.584418: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2023-08-23 16:20:48.686376: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2023-08-23 16:20:48.693940: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# WARNING:tensorflow:5 out of the last 9 calls to <function Model.make_test_function.<locals>.test_function at 0x15138fe50> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 9 calls to <function Model.make_test_function.<locals>.test_function at 0x1636d0670> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 9 calls to <function Model.make_test_function.<locals>.test_function at 0x140e8fe50> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 9 calls to <function Model.make_test_function.<locals>.test_function at 0x12f448a60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 9 calls to <function Model.make_test_function.<locals>.test_function at 0x161120a60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 9 calls to <function Model.make_test_function.<locals>.test_function at 0x14aee8670> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x1549995e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x166091670> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x1440985e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 9 calls to <function Model.make_test_function.<locals>.test_function at 0x144970a60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x161c505e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x1641d05e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x14d310670> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 9 calls to <function Model.make_test_function.<locals>.test_function at 0x14fb38a60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x147bb65e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x160d735e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2023-08-23 16:24:39.806156: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# Best parameters found:  {'activation': 'relu', 'batch_size': 10, 'dropout_rate': 0.2, 'epochs': 50}
# Best score 0.7515151560306549

# %%
# Define the model with the optimal parameters
def create_model():
    model = Sequential()
    model.add(Dense(16, input_dim=16, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(8, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

y_prob_dnn = np.zeros_like(y, dtype=float)

for train_idx, test_idx in cv.split(X_scaled, y):
    X_train, X_test = X_scaled[train_idx], X_scaled[test_idx]
    y_train, y_test = y[train_idx], y[test_idx]
    
    model = create_model()
    model.fit(X_train, y_train, epochs=50, batch_size=10, verbose=0)
    y_prob_dnn[test_idx] = model.predict(X_test).flatten()

y_pred_dnn = (y_prob_dnn > 0.5).astype(int)

print("DNN Model")
print("Predicted Probabilities:")
print(y_prob_dnn)
# Out:
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 141ms/step
# DNN Model
# Predicted Probabilities:
# [0.46740589 0.13564248 0.56062001 0.12186752 0.48579472 0.47259468
#  0.3105551  0.35688293 0.60757172 0.29256737 0.29593432 0.36278659
#  0.22582956 0.84875733 0.34943843 0.34331179 0.17761558 0.41070119
#  0.85166162 0.68970507 0.26189524 0.28296679 0.34284756 0.78717053
#  0.68041366 0.08296558 0.46072841 0.28578374 0.13716927 0.19801743
#  0.65321702 0.40151048 0.22846502 0.95091259 0.3335337  0.35874563
#  0.25670996 0.08191212 0.33251294 0.68876779 0.51046091 0.15130374
#  0.13343748 0.59019315 0.37315831 0.16010296 0.72726858 0.66994154
#  0.42613107 0.09658253 0.11949089 0.43812817 0.0908616  0.00446147
#  0.23355436 0.7072348  0.30392814 0.41575891 0.61152327 0.61971337
#  0.71133214 0.13757159 0.7183128  0.17751862 0.60345221 0.83981025
#  0.32994995 0.7872355  0.52254307 0.31338719 0.17074706 0.17658889
#  0.03853428 0.51769137 0.38581932 0.27246091 0.09353026 0.69343567
#  0.41208854 0.73489195 0.29964823 0.14419813 0.76911986 0.56957465
#  0.57532907 0.52099907 0.4087761  0.69412851 0.90162253 0.42831776
#  0.32016549 0.86002761 0.81629074 0.30742103 0.35244107 0.27748144
#  0.29226249 0.80260026 0.92877686 0.28023538 0.07639735 0.83410466
#  0.06798837 0.86182094 0.88641596 0.33639187 0.18020116 0.55768341
#  0.45095944 0.93786073 0.5766266  0.19769505 0.0772709  0.38865396
#  0.22914463]

# %%
mat_dnn = confusion_matrix(y, y_pred_dnn)
sns.heatmap(mat_dnn.T, square=True, annot=True, fmt='d', cmap='RdPu')
plt.xlabel('True label')
plt.ylabel('Predicted label')
plt.title("DNN")
plt.show()

print("Accuracy:\t%f" % accuracy_score(y, y_pred_dnn))
print("F1-score:\t%f" % f1_score(y, y_pred_dnn))
print("Precision:\t%f" % precision_score(y, y_pred_dnn))
print("Recall:\t\t%f" % recall_score(y, y_pred_dnn))
print("\nClassification performance:\n%s" % classification_report(y, y_pred_dnn))
# Out:
# Accuracy:	0.669565
# F1-score:	0.595745
# Precision:	0.666667
# Recall:		0.538462
#
# Classification performance:
#               precision    recall  f1-score   support
#
#            0       0.67      0.78      0.72        63
#            1       0.67      0.54      0.60        52
#
#     accuracy                           0.67       115
#    macro avg       0.67      0.66      0.66       115
# weighted avg       0.67      0.67      0.66       115

# %% [markdown]
# ### Integrated Models

# %% [markdown]
# ### XGBoost（Extreme Gradient Boosting）

# %%
import xgboost as xgb

# %%
param_grid = {
    'learning_rate': [0.01, 0.05, 0.1],
    'n_estimators': [100, 500, 1000],
    'max_depth': [3, 5, 7],
    'subsample': [0.7, 0.9],
    'colsample_bytree': [0.7, 0.9]
}

xgb_model = xgb.XGBClassifier()
grid_search = GridSearchCV(xgb_model, param_grid, cv=10, scoring='accuracy')
grid_search.fit(X, y)

print("Best parameters for XGBoost: ", grid_search.best_params_)
# Out:
# Best parameters for XGBoost:  {'colsample_bytree': 0.7, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 1000, 'subsample': 0.7}

# %%
xgb_model = xgb.XGBClassifier(
    colsample_bytree=0.7, 
    learning_rate=0.01, 
    max_depth=3, 
    n_estimators=1000, 
    subsample=0.7,
    use_label_encoder=False
)

y_prob_xgb = np.zeros_like(y, dtype=float)

for train_idx, test_idx in cv.split(X, y):
    X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
    y_train, y_test = y.iloc[train_idx], y.iloc[test_idx]
    
    xgb_model.fit(X_train, y_train)
    y_prob_xgb[test_idx] = xgb_model.predict_proba(X_test)[:, 1]

y_pred_xgb = (y_prob_xgb > 0.5).astype(int)

print("\nPredicted Probabilities for XGBoost:")
print(y_prob_xgb)
# Out:
# Predicted Probabilities for XGBoost:
# [0.57385433 0.109377   0.57729733 0.16644289 0.3959406  0.07496826
#  0.52090079 0.07519809 0.5384379  0.0665881  0.38423386 0.17714851
#  0.10956581 0.62305874 0.32941368 0.24583505 0.04286385 0.7170223
#  0.94846588 0.54104316 0.08190372 0.01563583 0.53831351 0.76018566
#  0.67758399 0.0850991  0.06198696 0.1667403  0.09916193 0.14790693
#  0.74320668 0.38508067 0.0951194  0.88445324 0.15456787 0.5741899
#  0.57984096 0.21517839 0.75104028 0.77013528 0.27385479 0.12611507
#  0.35409269 0.98223478 0.06557417 0.36821231 0.93600166 0.89645517
#  0.14651509 0.01494374 0.02916722 0.15143393 0.7559948  0.07477739
#  0.73108524 0.87137836 0.53434098 0.46789089 0.49235174 0.75049448
#  0.6402393  0.09431431 0.73405403 0.15142122 0.60007733 0.46882737
#  0.23378758 0.87428123 0.72669774 0.08446048 0.36837128 0.02107158
#  0.08663954 0.17144133 0.7463147  0.13193089 0.04622432 0.76582974
#  0.52921802 0.8360306  0.72131962 0.16240576 0.51477557 0.82158983
#  0.18306981 0.53988415 0.81544387 0.67819417 0.91682541 0.70027477
#  0.62263906 0.52996844 0.17893428 0.49336123 0.33404082 0.3620649
#  0.20719944 0.77142626 0.73729771 0.80359733 0.03125346 0.92295837
#  0.01804264 0.89414281 0.89420283 0.44777519 0.26617733 0.04408435
#  0.63401425 0.89675564 0.52514261 0.03150778 0.07476956 0.77183229
#  0.05670285]

# %%
mat_xgb = confusion_matrix(y, y_pred_xgb)
sns.heatmap(mat_xgb.T, square=True, annot=True, fmt='d', cmap='RdPu')
plt.xlabel('True label')
plt.ylabel('Predicted label')
plt.title("XGboost")
plt.show()

print("Accuracy:\t%f" % accuracy_score(y, y_pred_xgb))
print("F1-score:\t%f" % f1_score(y, y_pred_xgb))
print("Precision:\t%f" % precision_score(y, y_pred_xgb))
print("Recall:\t\t%f" % recall_score(y, y_pred_xgb))
print("\nClassification performance:\n%s" % classification_report(y, y_pred_xgb))
# Out:
# Accuracy:	0.686957
# F1-score:	0.660377
# Precision:	0.648148
# Recall:		0.673077
#
# Classification performance:
#               precision    recall  f1-score   support
#
#            0       0.72      0.70      0.71        63
#            1       0.65      0.67      0.66        52
#
#     accuracy                           0.69       115
#    macro avg       0.68      0.69      0.69       115
# weighted avg       0.69      0.69      0.69       115

# %% [markdown]
# ### CatBoost

# %% [markdown]
# CatBoost's main advantage: It uses a special algorithm to encode classification features that often works better than traditional One-Hot Encoding or Label Encoding. Because it is not necessary to use the encoded dataset for training catboost, the original dataset can be used.

# %%
from catboost import CatBoostClassifier, Pool, cv
import catboost as cb

# %%
df= pd.read_csv('/Users/quinne/Desktop/dissertation_dataset/halftime_dataframe_R.csv')
df
# Out:
#     Result  match_number                    team              opponent  \
# 0      win             5        Oval Invincibles         London Spirit
# 1      win             6      Birmingham Phoenix  Manchester Originals
# 2      win             7  Northern Superchargers         Trent Rockets
# 3     lose             8              Welsh Fire        Southern Brave
# 4      win            10           Trent Rockets         London Spirit
# ..     ...           ...                     ...                   ...
# 110   lose            30           London Spirit    Birmingham Phoenix
# 111    win            31  Northern Superchargers        Southern Brave
# 112   lose            32        Oval Invincibles  Manchester Originals
# 113   lose            40           London Spirit  Manchester Originals
# 114   lose            50    Manchester Originals         Trent Rockets
#
#      gender  season  team_score  team_wickets                  winner  \
# 0    female    2021         132             7        Oval Invincibles
# 1    female    2021         113             9      Birmingham Phoenix
# 2    female    2021         149             7  Northern Superchargers
# 3    female    2021         110             7          Southern Brave
# 4    female    2021         151             4           Trent Rockets
# ..      ...     ...         ...           ...                     ...
# 110    male    2022         139             6      Birmingham Phoenix
# 111    male    2022         135             8  Northern Superchargers
# 112    male    2022         143             9    Manchester Originals
# 113    male    2022         150             7    Manchester Originals
# 114    male    2022         120             9           Trent Rockets
#
#                 toss_winner home_advantage  \
# 0             London Spirit             no
# 1        Birmingham Phoenix             no
# 2    Northern Superchargers             no
# 3            Southern Brave            yes
# 4             Trent Rockets             no
# ..                      ...            ...
# 110      Birmingham Phoenix            yes
# 111          Southern Brave            yes
# 112        Oval Invincibles             no
# 113           London Spirit             no
# 114    Manchester Originals             no
#
#                                  venue_city choose_to_bat   avg_score  \
# 0                     Lord's, London London            no  139.000000
# 1       Old Trafford, Manchester Manchester           yes  128.000000
# 2       Trent Bridge, Nottingham Nottingham           yes  131.000000
# 3           Sophia Gardens, Cardiff Cardiff            no  130.000000
# 4                     Lord's, London London           yes  116.000000
# ..                                      ...           ...         ...
# 110                   Lord's, London London            no  140.642857
# 111                 Headingley, Leeds Leeds            no  152.714286
# 112     Old Trafford, Manchester Manchester           yes  145.500000
# 113  The Rose Bowl, Southampton Southampton           yes  140.533333
# 114                   Lord's, London London           yes  148.800000
#
#      avg_win_rate  avg_wickets_out last_match_result
# 0        1.000000         5.000000               win
# 1        0.000000         6.000000              lose
# 2        1.000000         4.000000               win
# 3        0.000000         8.000000              lose
# 4        0.000000         7.000000              lose
# ..            ...              ...               ...
# 110      0.428571         6.571429              lose
# 111      0.428571         6.000000               win
# 112      0.571429         5.785714               win
# 113      0.400000         6.533333              lose
# 114      0.533333         6.000000               win
#
# [115 rows x 17 columns]

# %%
# Transforming the 'Result' column to binary format
df['Result'] = df['Result'].apply(lambda x: 1 if x == 'win' else 0)

# %%
# Splitting the data into X (features) and y (target)
X = df.drop(columns=['Result'])
y = df['Result']

# List of categorical features
cat_features = [
    'team', 'opponent', 'gender', 'home_advantage', 'venue_city', 
    'toss_winner', 'winner', 'choose_to_bat', 'last_match_result'
]

# %%
# Initialize a base model
model = CatBoostClassifier(cat_features=cat_features, verbose=0)

# Parameter grid
grid = {
    'learning_rate': [0.01, 0.05, 0.1],
    'iterations': [100, 500, 1000],
    'depth': [3, 5, 7],
    'l2_leaf_reg': [1, 3, 5]
}

# Grid search
grid_search_result = model.grid_search(grid, 
                                       X=Pool(X, label=y, cat_features=cat_features), 
                                       cv=10,  
                                       plot=False)

# Best parameters from grid search
best_params = grid_search_result['params']
# Out:
# bestTest = 0.6460298114
# bestIteration = 83
#
# 0:	loss: 0.6460298	best: 0.6460298 (0)	total: 145ms	remaining: 11.6s
#
# bestTest = 0.6380247496
# bestIteration = 8
#
# 1:	loss: 0.6380247	best: 0.6380247 (1)	total: 260ms	remaining: 10.3s
#
# bestTest = 0.632254591
# bestIteration = 8
#
# 2:	loss: 0.6322546	best: 0.6322546 (2)	total: 371ms	remaining: 9.66s
#
# bestTest = 0.6411599294
# bestIteration = 84
#
# 3:	loss: 0.6411599	best: 0.6322546 (2)	total: 469ms	remaining: 9.02s
#
# bestTest = 0.6310070031
# bestIteration = 47
#
# 4:	loss: 0.6310070	best: 0.6310070 (4)	total: 555ms	remaining: 8.43s
#
# bestTest = 0.626970699
# bestIteration = 8
#
# 5:	loss: 0.6269707	best: 0.6269707 (5)	total: 684ms	remaining: 8.55s
#
# bestTest = 0.6485946045
# bestIteration = 95
#
# 6:	loss: 0.6485946	best: 0.6269707 (5)	total: 791ms	remaining: 8.36s
#
# bestTest = 0.6406715345
# bestIteration = 19
#
# 7:	loss: 0.6406715	best: 0.6269707 (5)	total: 881ms	remaining: 8.04s
#
# bestTest = 0.62043951
# bestIteration = 51
#
# 8:	loss: 0.6204395	best: 0.6204395 (8)	total: 1.02s	remaining: 8.16s
#
# bestTest = 0.006848419293
# bestIteration = 497
#
# 9:	loss: 0.0068484	best: 0.0068484 (9)	total: 1.67s	remaining: 11.8s
#
# bestTest = 0.0005930448486
# bestIteration = 499
#
# 10:	loss: 0.0005930	best: 0.0005930 (10)	total: 2.23s	remaining: 14.2s
#
# bestTest = 0.0003869899108
# bestIteration = 499
#
# 11:	loss: 0.0003870	best: 0.0003870 (11)	total: 2.69s	remaining: 15.5s
#
# bestTest = 0.01485321404
# bestIteration = 499
#
# 12:	loss: 0.0148532	best: 0.0003870 (11)	total: 3.34s	remaining: 17.5s
#
# bestTest = 0.000919268814
# bestIteration = 499
#
# 13:	loss: 0.0009193	best: 0.0003870 (11)	total: 3.89s	remaining: 18.6s
#
# bestTest = 0.0004849559368
# bestIteration = 498
#
# 14:	loss: 0.0004850	best: 0.0003870 (11)	total: 4.42s	remaining: 19.5s
#
# bestTest = 0.02052573971
# bestIteration = 499
#
# 15:	loss: 0.0205257	best: 0.0003870 (11)	total: 5.01s	remaining: 20.4s
#
# bestTest = 0.001295327323
# bestIteration = 499
#
# 16:	loss: 0.0012953	best: 0.0003870 (11)	total: 5.6s	remaining: 21.1s
#
# bestTest = 0.0007727745928
# bestIteration = 488
#
# 17:	loss: 0.0007728	best: 0.0003870 (11)	total: 6.18s	remaining: 21.6s
#
# bestTest = 0.00150666332
# bestIteration = 998
#
# 18:	loss: 0.0015067	best: 0.0003870 (11)	total: 7.46s	remaining: 24.3s
#
# bestTest = 0.0005441264142
# bestIteration = 999
#
# 19:	loss: 0.0005441	best: 0.0003870 (11)	total: 8.4s	remaining: 25.6s
#
# bestTest = 0.000332683724
# bestIteration = 999
#
# 20:	loss: 0.0003327	best: 0.0003327 (20)	total: 9.35s	remaining: 26.7s
#
# bestTest = 0.003455015742
# bestIteration = 999
#
# 21:	loss: 0.0034550	best: 0.0003327 (20)	total: 10.7s	remaining: 28.7s
#
# bestTest = 0.0005050935424
# bestIteration = 999
#
# 22:	loss: 0.0005051	best: 0.0003327 (20)	total: 11.8s	remaining: 29.7s
#
# bestTest = 0.0003934880926
# bestIteration = 999
#
# 23:	loss: 0.0003935	best: 0.0003327 (20)	total: 12.8s	remaining: 30.4s
#
# bestTest = 0.005565903098
# bestIteration = 998
#
# 24:	loss: 0.0055659	best: 0.0003327 (20)	total: 13.9s	remaining: 31.2s
#
# bestTest = 0.0005933060745
# bestIteration = 998
#
# 25:	loss: 0.0005933	best: 0.0003327 (20)	total: 15.2s	remaining: 32.1s
#
# bestTest = 0.0006525570475
# bestIteration = 988
#
# 26:	loss: 0.0006526	best: 0.0003327 (20)	total: 16.2s	remaining: 32.4s
#
# bestTest = 0.6375586682
# bestIteration = 86
#
# 27:	loss: 0.6375587	best: 0.0003327 (20)	total: 16.4s	remaining: 31s
#
# bestTest = 0.6516503802
# bestIteration = 10
#
# 28:	loss: 0.6516504	best: 0.0003327 (20)	total: 16.6s	remaining: 29.7s
#
# bestTest = 0.6150518439
# bestIteration = 47
#
# 29:	loss: 0.6150518	best: 0.0003327 (20)	total: 16.8s	remaining: 28.5s
#
# bestTest = 0.6270247438
# bestIteration = 96
#
# 30:	loss: 0.6270247	best: 0.0003327 (20)	total: 16.9s	remaining: 27.3s
#
# bestTest = 0.6375433378
# bestIteration = 49
#
# 31:	loss: 0.6375433	best: 0.0003327 (20)	total: 17.1s	remaining: 26.1s
#
# bestTest = 0.6021558249
# bestIteration = 18
#
# 32:	loss: 0.6021558	best: 0.0003327 (20)	total: 17.2s	remaining: 25s
#
# bestTest = 0.6364853853
# bestIteration = 89
#
# 33:	loss: 0.6364854	best: 0.0003327 (20)	total: 17.3s	remaining: 23.9s
#
# bestTest = 0.5886152323
# bestIteration = 84
#
# 34:	loss: 0.5886152	best: 0.0003327 (20)	total: 17.5s	remaining: 23s
#
# bestTest = 0.6156048239
# bestIteration = 23
#
# 35:	loss: 0.6156048	best: 0.0003327 (20)	total: 17.6s	remaining: 22s
#
# bestTest = 0.004527370295
# bestIteration = 499
#
# 36:	loss: 0.0045274	best: 0.0003327 (20)	total: 18.5s	remaining: 22s
#
# bestTest = 0.0005143301551
# bestIteration = 499
#
# 37:	loss: 0.0005143	best: 0.0003327 (20)	total: 19.3s	remaining: 21.8s
#
# bestTest = 0.0003689562864
# bestIteration = 499
#
# 38:	loss: 0.0003690	best: 0.0003327 (20)	total: 20.1s	remaining: 21.6s
#
# bestTest = 0.01058286159
# bestIteration = 499
#
# 39:	loss: 0.0105829	best: 0.0003327 (20)	total: 20.9s	remaining: 21.5s
#
# bestTest = 0.001106241665
# bestIteration = 498
#
# 40:	loss: 0.0011062	best: 0.0003327 (20)	total: 21.8s	remaining: 21.3s
#
# bestTest = 0.0004855306077
# bestIteration = 499
#
# 41:	loss: 0.0004855	best: 0.0003327 (20)	total: 22.8s	remaining: 21.1s
#
# bestTest = 0.02064683712
# bestIteration = 499
#
# 42:	loss: 0.0206468	best: 0.0003327 (20)	total: 23.7s	remaining: 20.9s
#
# bestTest = 0.002536176911
# bestIteration = 499
#
# 43:	loss: 0.0025362	best: 0.0003327 (20)	total: 24.4s	remaining: 20.6s
#
# bestTest = 0.002096537123
# bestIteration = 499
#
# 44:	loss: 0.0020965	best: 0.0003327 (20)	total: 25.4s	remaining: 20.3s
#
# bestTest = 0.001018092952
# bestIteration = 999
#
# 45:	loss: 0.0010181	best: 0.0003327 (20)	total: 27s	remaining: 20.6s
#
# bestTest = 0.0004492725694
# bestIteration = 999
#
# 46:	loss: 0.0004493	best: 0.0003327 (20)	total: 28.4s	remaining: 20.6s
#
# bestTest = 0.0003247836685
# bestIteration = 999
#
# 47:	loss: 0.0003248	best: 0.0003248 (47)	total: 29.7s	remaining: 20.4s
#
# bestTest = 0.003425391798
# bestIteration = 999
#
# 48:	loss: 0.0034254	best: 0.0003248 (47)	total: 31.5s	remaining: 20.6s
#
# bestTest = 0.000580265713
# bestIteration = 999
#
# 49:	loss: 0.0005803	best: 0.0003248 (47)	total: 32.9s	remaining: 20.4s
#
# bestTest = 0.0003775650658
# bestIteration = 997
#
# 50:	loss: 0.0003776	best: 0.0003248 (47)	total: 34.5s	remaining: 20.3s
#
# bestTest = 0.007212933389
# bestIteration = 999
#
# 51:	loss: 0.0072129	best: 0.0003248 (47)	total: 36.1s	remaining: 20.1s
#
# bestTest = 0.001303279698
# bestIteration = 999
#
# 52:	loss: 0.0013033	best: 0.0003248 (47)	total: 38s	remaining: 20.1s
#
# bestTest = 0.001111886065
# bestIteration = 999
#
# 53:	loss: 0.0011119	best: 0.0003248 (47)	total: 39.8s	remaining: 19.9s
#
# bestTest = 0.6264910736
# bestIteration = 89
#
# 54:	loss: 0.6264911	best: 0.0003248 (47)	total: 39.9s	remaining: 18.9s
#
# bestTest = 0.6257719236
# bestIteration = 18
#
# 55:	loss: 0.6257719	best: 0.0003248 (47)	total: 40.1s	remaining: 17.9s
#
# bestTest = 0.6494769609
# bestIteration = 2
#
# 56:	loss: 0.6494770	best: 0.0003248 (47)	total: 40.3s	remaining: 17s
#
# bestTest = 0.6385774231
# bestIteration = 86
#
# 57:	loss: 0.6385774	best: 0.0003248 (47)	total: 40.5s	remaining: 16.1s
#
# bestTest = 0.6360622517
# bestIteration = 51
#
# 58:	loss: 0.6360623	best: 0.0003248 (47)	total: 40.7s	remaining: 15.2s
#
# bestTest = 0.6411748198
# bestIteration = 5
#
# 59:	loss: 0.6411748	best: 0.0003248 (47)	total: 40.9s	remaining: 14.3s
#
# bestTest = 0.6450656003
# bestIteration = 99
#
# 60:	loss: 0.6450656	best: 0.0003248 (47)	total: 41.1s	remaining: 13.5s
#
# bestTest = 0.6300874926
# bestIteration = 57
#
# 61:	loss: 0.6300875	best: 0.0003248 (47)	total: 41.4s	remaining: 12.7s
#
# bestTest = 0.6260445333
# bestIteration = 18
#
# 62:	loss: 0.6260445	best: 0.0003248 (47)	total: 41.6s	remaining: 11.9s
#
# bestTest = 0.008408412875
# bestIteration = 499
#
# 63:	loss: 0.0084084	best: 0.0003248 (47)	total: 42.8s	remaining: 11.4s
#
# bestTest = 0.001064416988
# bestIteration = 499
#
# 64:	loss: 0.0010644	best: 0.0003248 (47)	total: 44.1s	remaining: 10.9s
#
# bestTest = 0.0008642528386
# bestIteration = 499
#
# 65:	loss: 0.0008643	best: 0.0003248 (47)	total: 45.4s	remaining: 10.3s
#
# bestTest = 0.01805715469
# bestIteration = 499
#
# 66:	loss: 0.0180572	best: 0.0003248 (47)	total: 46.5s	remaining: 9.72s
#
# bestTest = 0.003623244912
# bestIteration = 499
#
# 67:	loss: 0.0036232	best: 0.0003248 (47)	total: 47.8s	remaining: 9.14s
#
# bestTest = 0.003831588635
# bestIteration = 498
#
# 68:	loss: 0.0038316	best: 0.0003248 (47)	total: 49.1s	remaining: 8.54s
#
# bestTest = 0.02899073716
# bestIteration = 499
#
# 69:	loss: 0.0289907	best: 0.0003248 (47)	total: 50.3s	remaining: 7.9s
#
# bestTest = 0.008173384695
# bestIteration = 499
#
# 70:	loss: 0.0081734	best: 0.0003248 (47)	total: 51.6s	remaining: 7.27s
#
# bestTest = 0.005197592215
# bestIteration = 499
#
# 71:	loss: 0.0051976	best: 0.0003248 (47)	total: 53s	remaining: 6.62s
#
# bestTest = 0.003504268813
# bestIteration = 999
#
# 72:	loss: 0.0035043	best: 0.0003248 (47)	total: 55.6s	remaining: 6.1s
#
# bestTest = 0.0008286581688
# bestIteration = 999
#
# 73:	loss: 0.0008287	best: 0.0003248 (47)	total: 58s	remaining: 5.49s
#
# bestTest = 0.0007520483156
# bestIteration = 999
#
# 74:	loss: 0.0007520	best: 0.0003248 (47)	total: 1m	remaining: 4.82s
#
# bestTest = 0.00842631472
# bestIteration = 999
#
# 75:	loss: 0.0084263	best: 0.0003248 (47)	total: 1m 2s	remaining: 4.12s
#
# bestTest = 0.002374163628
# bestIteration = 999
#
# 76:	loss: 0.0023742	best: 0.0003248 (47)	total: 1m 5s	remaining: 3.38s
#
# bestTest = 0.003286873556
# bestIteration = 999
#
# 77:	loss: 0.0032869	best: 0.0003248 (47)	total: 1m 7s	remaining: 2.59s
#
# bestTest = 0.01628018661
# bestIteration = 999
#
# 78:	loss: 0.0162802	best: 0.0003248 (47)	total: 1m 9s	remaining: 1.76s
#
# bestTest = 0.005908636592
# bestIteration = 999
#
# 79:	loss: 0.0059086	best: 0.0003248 (47)	total: 1m 12s	remaining: 903ms
#
# bestTest = 0.003821948191
# bestIteration = 999
#
# 80:	loss: 0.0038219	best: 0.0003248 (47)	total: 1m 14s	remaining: 0us
# Estimating final quality...
# Training on fold [0/10]
#
# bestTest = 0.001258272136
# bestIteration = 999
#
# Training on fold [1/10]
#
# bestTest = 0.0005904891161
# bestIteration = 999
#
# Training on fold [2/10]
#
# bestTest = 0.0699749845
# bestIteration = 26
#
# Training on fold [3/10]
#
# bestTest = 0.02933179059
# bestIteration = 373
#
# Training on fold [4/10]
#
# bestTest = 0.01718940454
# bestIteration = 223
#
# Training on fold [5/10]
#
# bestTest = 0.0002798104125
# bestIteration = 999
#
# Training on fold [6/10]
#
# bestTest = 0.0008964445415
# bestIteration = 999
#
# Training on fold [7/10]
#
# bestTest = 0.0002594459714
# bestIteration = 998
#
# Training on fold [8/10]
#
# bestTest = 0.0002966705281
# bestIteration = 999
#
# Training on fold [9/10]
#
# bestTest = 0.0007452782328
# bestIteration = 999

# %%
print("Best parameters for CatBoost: ", best_params)
# Out:
# Best parameters for CatBoost:  {'depth': 5, 'l2_leaf_reg': 1, 'iterations': 1000, 'learning_rate': 0.1}

# %%
# Initialize the CatBoost model with the best parameters
model = CatBoostClassifier(
    depth=5, 
    l2_leaf_reg=1, 
    iterations=1000, 
    learning_rate=0.1,
    cat_features=cat_features,
    verbose=0  
)

# Train the model on the entire dataset
model.fit(X, y)

# %%
# Train# 10-fold cross-validation
cv = StratifiedKFold(n_splits=10, shuffle=True, random_state=5)
y_prob_catboost = np.zeros_like(y, dtype=float)

for train_idx, test_idx in cv.split(X, y):
    X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
    y_train, y_test = y.iloc[train_idx], y.iloc[test_idx]
    
    model.fit(X_train, y_train)
    y_prob_catboost[test_idx] = model.predict_proba(X_test)[:, 1]

y_pred_catboost = (y_prob_catboost > 0.5).astype(int)

print("\nPredicted Probabilities for CatBoost:")
print(y_prob_catboost)
# Out:
# Predicted Probabilities for CatBoost:
# [9.99928228e-01 9.98636803e-01 9.98931602e-01 2.43345850e-03
#  9.96666095e-01 8.60029723e-05 7.06914929e-03 9.99241288e-01
#  9.97146111e-01 7.19840680e-05 9.28130871e-01 8.76129478e-04
#  8.00160672e-05 2.43208597e-04 1.02009900e-04 1.73956136e-04
#  5.85969306e-05 1.15487256e-04 9.98030425e-01 2.42827144e-04
#  3.06570046e-05 8.30312437e-05 1.35642474e-04 9.99562183e-01
#  9.99864795e-01 3.22186649e-04 9.99432233e-01 9.99748041e-01
#  2.62035812e-04 1.15647023e-04 9.99012082e-01 9.97646012e-01
#  2.82539827e-04 6.18235374e-04 3.60519315e-04 1.48863420e-04
#  9.99726248e-01 6.61077770e-05 9.99714392e-01 3.58078564e-04
#  1.76101112e-04 4.48624825e-05 9.99651888e-01 9.99841267e-01
#  9.90689347e-01 6.65372078e-05 9.99315922e-01 9.99834358e-01
#  2.90097488e-04 7.80944008e-05 1.09741140e-04 5.15325804e-05
#  6.74345200e-01 1.04224483e-04 9.99896563e-01 1.16566230e-04
#  3.76160558e-04 9.99758569e-01 9.99712680e-01 9.99766432e-01
#  9.99759000e-01 7.20744432e-05 9.99501766e-01 3.53332562e-05
#  9.99905983e-01 9.99771132e-01 9.97382603e-01 4.84900325e-02
#  9.99246867e-01 5.13417800e-05 2.04321204e-04 6.83456233e-05
#  9.90159571e-01 1.04892135e-04 9.99753484e-01 1.60378379e-04
#  2.57288426e-04 9.99871000e-01 9.99786339e-01 9.99705373e-01
#  1.60955759e-04 3.13115040e-04 9.98586402e-01 1.60893888e-03
#  1.35990198e-04 9.99810671e-01 9.99862346e-01 9.32988539e-05
#  9.99937410e-01 1.47558101e-04 9.98504997e-01 6.84592623e-05
#  9.99048277e-01 1.31177318e-04 1.76122277e-04 4.69035055e-05
#  9.97221776e-01 9.99932913e-01 9.99903706e-01 9.99858765e-01
#  3.34373761e-05 9.99866417e-01 1.24482622e-04 9.99941241e-01
#  9.90793024e-01 9.95813792e-05 3.85353696e-04 1.01262206e-04
#  9.99691288e-01 9.99938242e-01 1.48032428e-04 9.99333311e-01
#  6.40287488e-05 1.43783127e-04 8.76277433e-05]

# %%
mat_catboost = confusion_matrix(y, y_pred_catboost)  
sns.heatmap(mat_catboost.T, square=True, annot=True, fmt='d', cmap='RdPu')
plt.xlabel('True label')
plt.ylabel('Predicted label')
plt.title("Catboost")
plt.show()

print("Accuracy:\t%f" % accuracy_score(y, y_pred_catboost))  
print("F1-score:\t%f" % f1_score(y, y_pred_catboost))  
print("Precision:\t%f" % precision_score(y, y_pred_catboost))  
print("Recall:\t\t%f" % recall_score(y, y_pred_catboost))
print("\nClassification performance:\n%s" % classification_report(y, y_pred_catboost))
# Out:
# Accuracy:	0.991304
# F1-score:	0.990476
# Precision:	0.981132
# Recall:		1.000000
#
# Classification performance:
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99        63
#            1       0.98      1.00      0.99        52
#
#     accuracy                           0.99       115
#    macro avg       0.99      0.99      0.99       115
# weighted avg       0.99      0.99      0.99       115
